# %%
#importing basic libraries
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data1 = pd.read_csv("C:/Users/ABHINAV-PC/Downloads/Insurance Dataset.csv")

# %%
data1
# Out:
#           Area_Service Hospital County  Hospital Id          Age Gender  \
# 0           Western NY        Allegany         37.0     30 to 49      F
# 1           Western NY        Allegany         37.0  70 or Older      F
# 2           Western NY        Allegany         37.0     30 to 49      F
# 3           Western NY        Allegany         37.0      0 to 17      F
# 4           Western NY        Allegany         37.0  70 or Older      F
# ...                ...             ...          ...          ...    ...
# 1048570  New York City           Bronx       1169.0  70 or Older      F
# 1048571  New York City           Bronx       1169.0      0 to 17      F
# 1048572  New York City           Bronx       1169.0     50 to 69      M
# 1048573  New York City           Bronx       1169.0     30 to 49      F
# 1048574  New York City           Bronx       1169.0     50 to 69      M
#
#                  Cultural_group          ethnicity Days_spend_hsptl  \
# ...

# %%
type(data1)
# Out:
# pandas.core.frame.DataFrame

# %%
data1.shape
# Out:
# (1048575, 24)

# %%
data1.describe
# Out:
# <bound method NDFrame.describe of           Area_Service Hospital County  Hospital Id          Age Gender  \
# 0           Western NY        Allegany         37.0     30 to 49      F
# 1           Western NY        Allegany         37.0  70 or Older      F
# 2           Western NY        Allegany         37.0     30 to 49      F
# 3           Western NY        Allegany         37.0      0 to 17      F
# 4           Western NY        Allegany         37.0  70 or Older      F
# ...                ...             ...          ...          ...    ...
# 1048570  New York City           Bronx       1169.0  70 or Older      F
# 1048571  New York City           Bronx       1169.0      0 to 17      F
# 1048572  New York City           Bronx       1169.0     50 to 69      M
# 1048573  New York City           Bronx       1169.0     30 to 49      F
# 1048574  New York City           Bronx       1169.0     50 to 69      M
#
#                  Cultural_group          ethnicity Days_spend_hsptl  \
# ...

# %%
data1.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1048575 entries, 0 to 1048574
# Data columns (total 24 columns):
#  #   Column                                 Non-Null Count    Dtype
# ---  ------                                 --------------    -----
#  0   Area_Service                           1046119 non-null  object
#  1   Hospital County                        1046119 non-null  object
#  2   Hospital Id                            1046119 non-null  float64
#  3   Age                                    1048575 non-null  object
#  4   Gender                                 1048575 non-null  object
#  5   Cultural_group                         1048575 non-null  object
#  6   ethnicity                              1048575 non-null  object
#  7   Days_spend_hsptl                       1048575 non-null  object
#  8   Admission_type                         1048575 non-null  object
#  9   Home or self care,                     1048575 non-null  object
# ...

# %%
data1.isnull().sum()
# Out:
# Area_Service                             2456
# Hospital County                          2456
# Hospital Id                              2456
# Age                                         0
# Gender                                      0
# Cultural_group                              0
# ethnicity                                   0
# Days_spend_hsptl                            0
# Admission_type                              0
# Home or self care,                          0
# ccs_diagnosis_code                          0
# ccs_procedure_code                          0
# apr_drg_description                         0
# Code_illness                                0
# Mortality risk                             42
# Surg_Description                            0
# Weight_baby                                 0
# Abortion                                    0
# Emergency dept_yes/No                       0
# Tot_charg                                   0
# ...

# %%
data1.duplicated(keep='first').sum()
# Out:
# 4814

# %%
data1.drop_duplicates(keep='first',inplace=True)
data1.duplicated(keep='first').sum()
# Out:
# 0

# %%
data1.corr()
# Out:
#                                        Hospital Id  ccs_diagnosis_code  \
# Hospital Id                               1.000000            0.052710
# ccs_diagnosis_code                        0.052710            1.000000
# ccs_procedure_code                        0.019376            0.051225
# Code_illness                             -0.047538           -0.181650
# Mortality risk                           -0.041745           -0.269097
# Weight_baby                               0.039553            0.034792
# Tot_charg                                 0.021082           -0.076226
# Tot_cost                                  0.003548           -0.041853
# ratio_of_total_costs_to_total_charges     0.004917            0.030564
# Result                                   -0.001368            0.000351
# Payment_Typology                          0.149718           -0.074999
#
#                                        ccs_procedure_code  Code_illness  \
# ...

# %%
# Hence we can infer that Area Service is highly correlated with hospital county and columns Tot_cost and ratio_of_total_costs_to_total_charges are highly positivley skewed.
